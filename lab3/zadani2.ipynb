# %%
import pygad
import numpy as np
import math

# %% [markdown]
# ustawianie algorytmu

# %%
#geny to liczby: [0, 1)
#np. 0.09, 0.01, 0.4
gene_space = [i for i in np.arange(0, 1, 0.01)]

#funkcja oceniająca stop
def endurance(x, y, z, u, v, w):
    return math.exp(-2*(y-math.sin(x))**2)+math.sin(z*u)+math.cos(v*w)

#definiujemy funkcję fitness
def fitness_func(solution, solution_idx):
    fitness = endurance(*solution)
    return fitness

# funkcaj fitness
fitness_function = fitness_func

#ile chromsomów w populacji
sol_per_pop = 12
#ile genow ma chromosom
num_genes = 6
#ile wylaniamy rodzicow do "rozmanazania" (okolo 50% populacji)
num_parents_mating = 5
#ile pokolen
num_generations = 30
#ilu rodzicow zachowac (kilka procent)
keep_parents = 2
#jaki typ selekcji rodzicow?
#sss = steady, rws=roulette, rank = rankingowa, tournament = turniejowa
parent_selection_type = "sss"
#w il =u punktach robic krzyzowanie?
crossover_type = "single_point"
#mutacja ma dzialac na ilu procent genow?
#trzeba pamietac ile genow ma chromosom
mutation_type = "random"
mutation_percent_genes = 17

ga_instance = pygad.GA(gene_space=gene_space,
                       num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop,
                       num_genes=num_genes,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes)

# %%
for number in range(10):
    ga_instance.run()
    #podsumowanie: najlepsze znalezione rozwiazanie (chromosom+ocena)
    solution, solution_fitness, solution_idx = ga_instance.best_solution()
    print("Parameters of the best solution : {solution}".format(solution=solution))
    print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
    ga_instance.plot_fitness()
    print("-------------------------------------------------------------------")
# Out:
# Parameters of the best solution : [0.16 0.16 0.93 0.99 0.02 0.14]
# Fitness value of the best solution = 2.7960206495075464
# -------------------------------------------------------------------
# Parameters of the best solution : [0.16 0.16 0.94 0.99 0.   0.58]
# Fitness value of the best solution = 2.801977567276033
# -------------------------------------------------------------------
# Parameters of the best solution : [0.14 0.14 0.96 0.99 0.19 0.05]
# Fitness value of the best solution = 2.8136025707967223
# -------------------------------------------------------------------
# Parameters of the best solution : [0.14 0.14 0.98 0.99 0.08 0.02]
# Fitness value of the best solution = 2.8249970592581177
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.98 0.99 0.06 0.02]
# Fitness value of the best solution = 2.824998036742745
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.98 0.99 0.17 0.  ]
# Fitness value of the best solution = 2.8249987567426587
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.98 0.99 0.6  0.  ]
# Fitness value of the best solution = 2.8249987567426587
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.99 0.99 0.83 0.  ]
# Fitness value of the best solution = 2.830553068590512
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.99 0.99 0.28 0.  ]
# Fitness value of the best solution = 2.830553068590512
# -------------------------------------------------------------------
# Parameters of the best solution : [0.02 0.02 0.99 0.99 0.59 0.  ]
# Fitness value of the best solution = 2.830553068590512
# -------------------------------------------------------------------
