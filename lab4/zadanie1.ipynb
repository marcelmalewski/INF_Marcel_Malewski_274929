# %%
import pyswarms as ps
import matplotlib.pyplot as plt
from pyswarms.utils.functions import single_obj as fx
from pyswarms.utils.plotters import plot_cost_history

# %% [markdown]
# zadanie 1

# %%
# Set-up hyperparameters
options = {'c1': 0.5, 'c2': 0.3, 'w':0.92}

# Call instance of GlobalBestPSO
optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=2,
                                    options=options)

cost_history = optimizer.cost_history

# Perform optimization
stats = optimizer.optimize(fx.sphere, iters=100)

# Plot!
plot_cost_history(cost_history)
plt.show()
print(cost_history)
# Out:
# 2022-03-30 11:17:40,426 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.92}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=3.83e-6
# 2022-03-30 11:17:40,625 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 3.8309485144960424e-06, best pos: [ 0.0007111  -0.00182354]
# [0.2812353702947285, 0.2812353702947285, 0.2812353702947285, 0.2812353702947285, 0.2812353702947285, 0.1654228117635707, 0.012053202906777121, 0.012053202906777121, 0.012053202906777121, 0.012053202906777121, 0.004892383596684595, 0.004892383596684595, 0.004892383596684595, 0.004892383596684595, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.0007597484506854465, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.000429818664198449, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 0.00010899696039349074, 7.968173595828482e-05, 7.968173595828482e-05, 7.968173595828482e-05, 7.968173595828482e-05, 7.968173595828482e-05, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06, 3.8309485144960424e-06]

# %% [markdown]
# udało się osiągnąć: 1.5376659257893511e-07, best pos: [ 7.82357623e-05 -3.84247001e-04]

# %% [markdown]
# zadanie 2 dobrowolne

# %% [markdown]
# zadanie 3 pierwsze 2 taski

# %% [markdown]
# task 1 zadanie1 ackley
# udało się osiągnąć : best cost: 0.0027089200326604335, best pos: [ 0.00077928 -0.00054205]
# co jest znacznie lepszym rozwiązaniem

# %%
from pyswarms.utils.functions.single_obj import ackley

# Set-up hyperparameters
options = {'c1': 0.5, 'c2': 0.3, 'w':0.92}

# Call instance of GlobalBestPSO
optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=2,
                                    options=options)

cost_history = optimizer.cost_history

# Perform optimization
stats = optimizer.optimize(ackley, iters=100)

# Plot!
plot_cost_history(cost_history)
plt.show()
# Out:
# 2022-03-30 11:31:20,795 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.92}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=0.00271
# 2022-03-30 11:31:20,961 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0027089200326604335, best pos: [ 0.00077928 -0.00054205]

# %% [markdown]
# task 1 zadanie1 (booth)
# udało się osiągnąć: best cost: 1.1048153229856284e-06, best pos: [1.00076672 2.99948323]
# wynik nie jest tak dobry ale czas jest najlepszy puki co

# %%
from pyswarms.utils.functions.single_obj import booth

# Set-up hyperparameters
options = {'c1': 0.5, 'c2': 0.3, 'w':0.92}

# Call instance of GlobalBestPSO
optimizer = ps.single.GlobalBestPSO(n_particles=10, dimensions=2,
                                    options=options)

cost_history = optimizer.cost_history

# Perform optimization
stats = optimizer.optimize(booth, iters=100)

# Plot!
plot_cost_history(cost_history)
plt.show()
# Out:
# 2022-03-30 11:37:15,128 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.92}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=1.1e-6
# 2022-03-30 11:37:15,279 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 1.1048153229856284e-06, best pos: [1.00076672 2.99948323]

# %% [markdown]
# task 2 zadanie 1

# %%
#--------------------------------------------
import pyswarms.backend as P
from pyswarms.backend.swarms import Swarm
from pyswarms.backend.handlers import VelocityHandler
from pyswarms.backend.topology import Star

my_swarm = P.create_swarm(n_particles=10, dimensions=2)
my_topology = Star()
my_vh = VelocityHandler(strategy="adjust")

for i in range(10):
    # Inside the for-loop
    my_swarm.velocity = my_topology.update_velocity(my_swarm, clamp, my_vh, bounds)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [46], in <cell line: 20>()
#      18 my_vh = VelocityHandler(strategy="adjust")
#      20 for i in range(10):
#      21     # Inside the for-loop
# ---> 22     my_swarm.velocity = my_topology.update_velocity(my_swarm, clamp, my_vh, bounds)
#
# AttributeError: 'Star' object has no attribute 'update_velocity'
